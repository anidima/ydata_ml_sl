# %% [markdown]
# # Naive Bayes

# %% [markdown]
# ## 1. Classifying Digits
# In this part we will test digits classification on the MNIST dataset, using Bernoulli Naive Bayes (a generative model).
#
# The MNIST dataset contains 28x28 grayscale images of handwritten digits between 0 and 9 (10 classes). For mathmatical analysis clarity, and for matching expected API, flatten each image to create a 1D array with 784 elements.

# %% [markdown]
# ### Loading the MNIST dataset
# Load the MNIST data set. The digits dataset is one of datasets scikit-learn comes with that do not require the downloading of any file from some external website. Use
# >```
# from sklearn.datasets import fetch_openml
# X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
# ```
#
# Plot a single sample of each digit as the original image, so you get a feeling how the data looks like.
#
# Finally, divide your data into train and test sets, using 1/7 of the data for testing.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import fetch_openml
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
# Out:
# c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\datasets\_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 from sklearn.datasets import fetch_openml
# ----> 2 X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\datasets\_openml.py:1118, in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y, as_frame, n_retries, delay, parser, read_csv_kwargs)
#    1116 # obtain the data
#    1117 url = _DATA_FILE.format(data_description["file_id"])
# -> 1118 bunch = _download_data_to_bunch(
#    1119     url,
#    1120     return_sparse,
#    1121     data_home,
#    1122     as_frame=bool(as_frame),
#    1123     openml_columns_info=features_list,
#    1124     shape=shape,
#    1125     target_columns=target_columns,
#    1126     data_columns=data_columns,
#    1127     md5_checksum=data_description["md5_checksum"],
#    1128     n_retries=n_retries,
#    1129     delay=delay,
#    1130     parser=parser_,
#    1131     read_csv_kwargs=read_csv_kwargs,
#    1132 )
#    1134 if return_X_y:
#    1135     return bunch.data, bunch.target
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\datasets\_openml.py:669, in _download_data_to_bunch(url, sparse, data_home, as_frame, openml_columns_info, data_columns, target_columns, shape, md5_checksum, n_retries, delay, parser, read_csv_kwargs)
#     665     from pandas.errors import ParserError
#     667     no_retry_exception = ParserError
# --> 669 X, y, frame, categories = _retry_with_clean_cache(
#     670     url, data_home, no_retry_exception
#     671 )(_load_arff_response)(
#     672     url,
#     673     data_home,
#     674     parser=parser,
#     675     output_type=output_type,
#     676     openml_columns_info=features_dict,
#     677     feature_names_to_select=data_columns,
#     678     target_names_to_select=target_columns,
#     679     shape=shape,
#     680     md5_checksum=md5_checksum,
#     681     n_retries=n_retries,
#     682     delay=delay,
#     683     read_csv_kwargs=read_csv_kwargs,
#     684 )
#     686 return Bunch(
#     687     data=X,
#     688     target=y,
#    (...)
#     692     target_names=target_columns,
#     693 )
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\datasets\_openml.py:59, in _retry_with_clean_cache.<locals>.decorator.<locals>.wrapper(*args, **kw)
#      57     return f(*args, **kw)
#      58 try:
# ---> 59     return f(*args, **kw)
#      60 except URLError:
#      61     raise
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\datasets\_openml.py:534, in _load_arff_response(url, data_home, parser, output_type, openml_columns_info, feature_names_to_select, target_names_to_select, shape, md5_checksum, n_retries, delay, read_csv_kwargs)
#     524 arff_params: Dict = dict(
#     525     parser=parser,
#     526     output_type=output_type,
#    (...)
#     531     read_csv_kwargs=read_csv_kwargs or {},
#     532 )
#     533 try:
# --> 534     X, y, frame, categories = _open_url_and_load_gzip_file(
#     535         url, data_home, n_retries, delay, arff_params
#     536     )
#     537 except Exception as exc:
#     538     if parser != "pandas":
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\datasets\_openml.py:522, in _load_arff_response.<locals>._open_url_and_load_gzip_file(url, data_home, n_retries, delay, arff_params)
#     520 gzip_file = _open_openml_url(url, data_home, n_retries=n_retries, delay=delay)
#     521 with closing(gzip_file):
# --> 522     return load_arff_from_gzip_file(gzip_file, **arff_params)
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\datasets\_arff_parser.py:520, in load_arff_from_gzip_file(gzip_file, parser, output_type, openml_columns_info, feature_names_to_select, target_names_to_select, shape, read_csv_kwargs)
#     470 """Load a compressed ARFF file using a given parser.
#     471
#     472 Parameters
#    (...)
#     517     `output_array_type == "pandas"`.
#     518 """
#     519 if parser == "liac-arff":
# --> 520     return _liac_arff_parser(
#     521         gzip_file,
#     522         output_type,
#     523         openml_columns_info,
#     524         feature_names_to_select,
#     525         target_names_to_select,
#     526         shape,
#     527     )
#     528 elif parser == "pandas":
#     529     return _pandas_arff_parser(
#     530         gzip_file,
#     531         output_type,
#    (...)
#     535         read_csv_kwargs,
#     536     )
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\datasets\_arff_parser.py:197, in _liac_arff_parser(gzip_file, output_arrays_type, openml_columns_info, feature_names_to_select, target_names_to_select, shape)
#     195 columns_to_keep = [col for col in columns_names if col in columns_to_select]
#     196 dfs = [first_df[columns_to_keep]]
# --> 197 for data in _chunk_generator(arff_container["data"], chunksize):
#     198     dfs.append(
#     199         pd.DataFrame(data, columns=columns_names, copy=False)[columns_to_keep]
#     200     )
#     201 # dfs[0] contains only one row, which may not have enough data to infer to
#     202 # column's dtype. Here we use `dfs[1]` to configure the dtype in dfs[0]
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\utils\__init__.py:729, in _chunk_generator(gen, chunksize)
#     726 """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#     727 chunk may have a length less than ``chunksize``."""
#     728 while True:
# --> 729     chunk = list(islice(gen, chunksize))
#     730     if chunk:
#     731         yield chunk
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\externals\_arff.py:461, in DenseGeneratorData.decode_rows(self, stream, conversors)
#     460 def decode_rows(self, stream, conversors):
# --> 461     for row in stream:
#     462         values = _parse_values(row)
#     464         if isinstance(values, dict):
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\externals\_arff.py:864, in ArffDecoder._decode.<locals>.stream()
#     863 def stream():
# --> 864     for row in s:
#     865         self._current_line += 1
#     866         row = row.strip()
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\site-packages\sklearn\datasets\_arff_parser.py:161, in _liac_arff_parser.<locals>._io_to_generator(gzip_file)
#     160 def _io_to_generator(gzip_file):
# --> 161     for line in gzip_file:
#     162         yield line.decode("utf-8")
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\gzip.py:427, in GzipFile.readline(self, size)
#     425 def readline(self, size=-1):
#     426     self._check_not_closed()
# --> 427     return self._buffer.readline(size)
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File c:\Users\dmitr\miniconda3\envs\y_data\Lib\gzip.py:537, in _GzipReader.read(self, size)
#     535     uncompress = self._decompressor.decompress(buf, size)
#     536 else:
# --> 537     uncompress = self._decompressor.decompress(b"", size)
#     539 if self._decompressor.unused_data != b"":
#     540     # Prepend the already read bytes to the fileobj so they can
#     541     # be seen by _read_eof() and _read_gzip_header()
#     542     self._fp.prepend(self._decompressor.unused_data)
#
# KeyboardInterrupt:

# %%
numbers_list = list(np.arange(10))
plt.figure(figsize=(20, 3))
i = 0
for num in y:
    if len(numbers_list)>0:
        if int(num) in numbers_list:
            plt.subplot(1,10,int(num)+1)
            plt.imshow(np.array(X.iloc[i]).reshape((28,28)), cmap='binary')
            plt.tick_params(bottom=False, left=False, labelbottom=False, labelleft=False)
            i += 1
            numbers_list.remove(int(num))
        else:
            i += 1 
    else:
        break

# %%
# Finally, divide your data into train and test sets, using 1/7 of the data for testing.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/7, random_state=24)

# %% [markdown]
# ### Bernoulli Naive Bayes
# If we know how the digits are generated, then we know how to classify them (simply choose the digit class which will maximize the posterior probability) --- but which model should we use for describing the digits generation?
#
# In this part we will try a very simplified model of digits creation (which is obviously not the same as the "real" model), using a Naive Bayes over an underlying Bernoulli distribution --- that is, we will assume that given a digit class, the pixels of the images are the result of independent coin flips, each with its own "head" probability.
#
# Note that since we assume each pixl is either 0 (black) or 1 (white), we will need to adjust (preprocess) our data accrodingly (see below).
#
# So, the model is stated as follows:
# $$
# \begin{align}
# \text{Domain} && x \in \{0,1\}^{784} \\
# \text{Prior} && \pi_j = \Pr(y=j) \\
# \text{Likelihood} && P_j(x) = \Pr(x | y=j) \\
# \end{align}
# $$
#
# Where for each $i\in 0\ldots 784$ it holds that
# $$
# P_{ji}(x_i) = \Pr(x_i | y=j) =
# \begin{cases}
# p_{ji} & \text{if } x_i=1 \\
# 1-p_{ji} & \text{if } x_i=0 \\
# \end{cases}
# $$

# %% [markdown]
# #### Question 1
# Write the classification rule based on this Naive Bayes model.
# How would you esitmate each of the parameters of the model based on the trainning data?
#
#
# **Bonus:** Think of edge cases which may effect your estimator in an undesired way.

# %% [markdown]
# #### Answer 1
#
# The classification rule for the Naive Bayes model involves selecting the digit class that maximizes the posterior probability given the observed pixel values. For a given input vector of pixel values $x$, the classification rule is:
# $$ \hat{y} = \arg\max_{j} P(y=j | x) $$
# where $ \hat{y} $ is the predicted digit class, and $ P(y=j | x) $ is the posterior probability of class $ j $ given the observed pixel values $ x $.
#
# We know that posterior probability is calculated using Bayes' theorem:
# $$ P(y=j | x) = \frac{P(x | y=j) \cdot P(y=j)}{P(x)} $$
#
#
# In the Naive Bayes model, the independence assumption allows us to express the likelihood $ P(x∣y=j) $ as the product of individual pixel-wise probabilities:
# $$ P(x | y=j) = \prod_{i=1}^{784} P_{ji}(x_i) $$
#
# $$Prior = \frac{Number\: of\: instances\: in\: class\: j}{Total\: number\: of\: instances}$$
#
# Therefore, the classification rule simplifies to:
# $$ \hat{y} = \arg\max_{j} \left( \frac{N_j}{N_{\text{Total}}} \prod_{i=1}^{784} P_{ji}(x_i) \right) $$

# %% [markdown]
# Prior probability for each class:

# %%
y_train.value_counts() / len(y_train)
# Out:
# class
# 1    0.112867
# 7    0.103267
# 3    0.101933
# 2    0.099583
# 9    0.099183
# 6    0.099000
# 4    0.098233
# 0    0.098150
# 8    0.097100
# 5    0.090683
# Name: count, dtype: float64

# %% [markdown]
# #### Question 2
# Run a Naive Bayes classifier on the training data and apply predictions on the test data. Use the [sklearn.naive_bayes.BernoulliNB](http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.BernoulliNB.html) implementation (see the [source code for sklearn.naive_bayes](https://github.com/scikit-learn/scikit-learn/blob/master/sklearn/naive_bayes.py) for details).
#
# Remember we need to preprocess the data in this case such that each pixel would become either black (0) or white (1). For this, use the `binarize` parameter of the implementation. Set this value to $0$ (this is the default), which in this case would mean every pixel with non-zero value will be set to 1.
#
# 1. Plot the mean image of each class (estimated $\hat{p}_{ji}$) and generate one sample of each class (remember, you can do this since this is a generative model). You will need to access the `feature_log_prob_` attribute of the trained model.
#
# 2. Plot the confusion matrix of your classifier, as claculated on the test data (it is recommended to use [sklearn.metrics.confusion_matrix](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)). Calculate the total accuracy (fraction of correctly classified images), and summarize the results in your own words.
#
# 3. Think of a way you can find the optimal threshold of the binarization part. **There is no need to actually perform this task --- just describe what you would have done.**

# %% [markdown]
# #### Answer 2
# Put you answer here...

# %%
# code goes here
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import confusion_matrix, accuracy_score

nb_model = BernoulliNB(binarize=0)
nb_model.fit(X_train, y_train)

# Plot mean image for each class
plt.figure(figsize=(20, 2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(nb_model.feature_log_prob_[i].reshape(28, 28), cmap='binary')
    # remove ticks and axis labels
    plt.tick_params(bottom=False, left=False, labelbottom=False, labelleft=False)
plt.suptitle("Mean images of each class")


# Generate one sample for each class
plt.figure(figsize=(20,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    vec_generated = np.random.binomial(1,np.exp(nb_model.feature_log_prob_[i]), 784)
    plt.imshow(vec_generated.reshape(28, 28), cmap='binary')
    plt.tick_params(bottom=False, left=False, labelbottom=False, labelleft=False)
plt.suptitle("Generated images")

plt.show()

# %%
# Make predictions on the test set
y_pred = nb_model.predict(X_test)

# Plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

# Labeling the axes
classes = list(np.unique(y))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Print accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

plt.show()
# Out:
# Accuracy: 0.8288

# %% [markdown]
# ## 2. Classifing Text Documents using Multinomial Naive Bayes
# In this exercise you will classify the "20 newsgroups" data set using your own naive bayes classifier and compare to the scikit learn built in version.
#
# The 20 newsgroups dataset comprises around 18000 newsgroups posts on 20 topics split in two subsets: one for training (or development) and the other one for testing (or for performance evaluation). The split between the train and test set is based upon messages posted before and after a specific date.
#
#
# * Load the **train** data using `from sklearn.datasets import fetch_20newsgroups`. remove headers, footers and quotes (see documentation)
# * Use `sklearn.feature_extraction.text import CountVectorizer` to count words (stop_words='english')
# * Write a class `NaiveBayes(BaseEstimator, ClassifierMixin)` and implement its `fit`, `predict` and `predict_proba` methods.
# * use `sklearn.pipeline.make_pipeline` to chain the vectroizer and model.
# * note: limit the vocuabolary size if you suffer memory issues
# * compare the accuracy over the **test** data. You can use `accuracy_score, classification_report`
# * compare to the built in `sklearn.naive_bayes.MultinomialNB`. If there are differences try to think why
# * optimize performance in respect to vectorizer hyper parameters (e.g. max_features, max_df etc.).
#
# ### Optional: Model interpretability
# Find the most important features for a **specific** decision of a NB classifier.
# Because the model has learned the prior $p(x_i|c)$ during the training, the contribution of an individual feature value can be easily measured by the posterior, $p(c|x_i)=p(c)p(x_i|c)/p(x_i)$
# Implement a function which gets a scikit-learn NB model as input and returns $p(c|x_i)$:
#
# `def calc_p_c_given_xi(model)`
#
# Hint: Use the following model properties:
#
# * `model.class_log_prior_`
# * `model.feature_log_prob_`
#
# Note: remember these are logs and you need to use np.exp and normalize to get $P(c|x_i)$
# Another hint: use numpy built-in broadcasting property.
#
# * Use the interpretation to examine errors of the classifier where $\hat{c}\ne c$. Which top words support the correct class and which support the wrong class? You can use the `print_txt` below to color words.
#
# Bonus: How can you correct the analyzed error?
#
# To read more about model interpretation, see the blogpost below and my tutorial:
# * https://lilianweng.github.io/lil-log/2017/08/01/how-to-explain-the-prediction-of-a-machine-learning-model.html
# * https://github.com/Shaboodi/right_but_why

# %%
import string
def print_txt(txt, hot, cold):
  """
  print the text, coloring hot and cold words with colors
  """
  cold_color='\x1b[41;37m{}\x1b[0m'
  hot_color='\x1b[42;37m{}\x1b[0m'
  def color(token):
    lower = str(token).lower()
    lower = lower.replace('\t','').replace('\n','')
    lower = lower.translate(string.punctuation)
    if (lower in hot) and (lower in cold):
      return mid_color.format(token)
    elif lower in hot:
      return hot_color.format(token)
    elif lower in cold:
      return cold_color.format(token)
    else:
      return token
  colored_txt = " ".join([color(token) for token in txt.split(' ')])
  print(colored_txt)
print_txt('This word support the first class but this the other', ['word'],['other'])
# Out:
# This word support the first class but this the other

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.naive_bayes import MultinomialNB

import numpy as np

# %%
categories = ['alt.atheism', 'soc.religion.christian', 'comp.graphics', 'sci.med']
newsgroups_train = fetch_20newsgroups(subset='train', categories=categories, remove=('headers', 'footers', 'quotes'))
newsgroups_test = fetch_20newsgroups(subset='test', categories=categories, remove=('headers', 'footers', 'quotes'))
X_train = newsgroups_train.data
y_train = newsgroups_train.target
X_test = newsgroups_test.data
y_test = newsgroups_test.target

# %%
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(X_train)
#words = vectorizer.get_feature_names_out()

X2 = vectorizer.fit_transform(X_test)

# Check words
#file_path = 'my_array_file.txt'
#np.savetxt(file_path, words, fmt='%s')

# %%
class NaiveBayes(BaseEstimator, ClassifierMixin):
  def __init__(self):
        self.class_probs = None  # Class probabilities (Prior)
        self.word_probs = None   # Word probabilities for each class (Likelihood)
        self.classes = None      # Unique classes in the training data

  def fit(self, X, y):
        self.classes = np.unique(y)
        num_classes = len(self.classes)
        num_words = X.shape[1]

        # Calculate class probabilities (prior)
        self.class_probs = np.zeros(num_classes)
        for i, c in enumerate(self.classes):
            self.class_probs[i] = np.sum(y == c) / len(y)

        # Calculate word probabilities for each class (Likelihood)
        self.word_probs = np.zeros((num_classes, num_words))
        for i, c in enumerate(self.classes):
            class_docs = X[y == c]
            total_word_counts = np.sum(class_docs, axis=0)
            total_word_counts_per_class = np.sum(total_word_counts)
            self.word_probs[i, :] = (total_word_counts + 1) / (total_word_counts_per_class + num_words)
        pass


  def predict_log_proba(self, X):
      
      num_classes = len(self.classes)
      num_docs = X.shape[0]
      probs  = np.zeros((num_docs, num_classes))

      for i in range(num_classes):
            log_class_probs = np.log(self.class_probs[i])
            log_word_probs = np.log(self.word_probs[i, :])
            log_likelihood = X.dot(log_word_probs) + log_class_probs
            probs[:, i] = log_likelihood
      return probs
             

    
  def predict(self, X):
        predictions = np.argmax(self.predict_log_proba(X), axis=1)
        return self.classes[predictions]

# %%
# Create a pipeline with CountVectorizer and Naive Bayes model
pipeline = make_pipeline(
    vectorizer,
    NaiveBayes()
)

# %%
#compare the accuracy over the **test** data. You can use `accuracy_score, classification_report`

# Train the model using the pipeline
pipeline.fit(X_train, y_train)

# Make predictions on the test set
y_pred = pipeline.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8289

# %%
#compare to the built in `sklearn.naive_bayes.MultinomialNB`. If there are differences try to think why

pipeline_sk = make_pipeline(
    vectorizer,
    MultinomialNB()
)

# %%
pipeline_sk.fit(X_train, y_train)
y_pred_sk = pipeline_sk.predict(X_test)
accuracy = accuracy_score(y_test, y_pred_sk)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8289

# %%
max_features_values = [1000, 3000, 5000, 7000, 10000, 15000]
max_df_values = [0.2, 0.3, 0.5, 0.8, 0.95]
results = np.zeros((len(max_features_values), len(max_df_values)))

for i, max_features in enumerate(max_features_values):
    for j, max_df in enumerate(max_df_values):
        vectorizer = CountVectorizer(stop_words='english', max_features=max_features, max_df=max_df)
        nb_classifier = make_pipeline(vectorizer, NaiveBayes())
        nb_classifier.fit(X_train, y_train)
        nb_pred = nb_classifier.predict(X_test)

        accuracy = accuracy_score(y_test, nb_pred)
        #print(f"max_features={max_features}, max_df={max_df}: Accuracy = {accuracy:.4f}")
        results[i, j] = accuracy

# Plotting
fig, ax = plt.subplots(2, 1, figsize=(10, 12))

# Plot for max_features=15000, max_df all
ax[0].plot(max_df_values, results[-1, :], marker='o', label=f'max_features={max_features_values[-1]}')
ax[0].set_title('Accuracy for max_features=15000, max_df all')
ax[0].set_xlabel('max_df')
ax[0].set_ylabel('Accuracy')
ax[0].legend()

# Plot for max_df=0.5 and all max_features
ax[1].plot(max_features_values, results[:, 0], marker='o', label=f'max_df={max_df_values[0]}')
ax[1].set_title('Accuracy for max_df=0.5 and all max_features')
ax[1].set_xlabel('max_features')
ax[1].set_ylabel('Accuracy')
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
vectorizer = CountVectorizer(stop_words='english')
X_train_v = vectorizer.fit_transform(X_train)

sk_nb_model = MultinomialNB()
sk_nb_model.fit(X_train_v, y_train)

print(sk_nb_model.class_log_prior_.shape)
sk_nb_model.feature_log_prob_.shape
# Out:
# (4,)
# (4, 28559)

# %%
def calc_p_c_given_xi(model):
    pass
